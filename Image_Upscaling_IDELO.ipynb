# %% [markdown]
# <a href="https://colab.research.google.com/github/anustupdas/googleCollab_NOtebook_computer_vision/blob/main/Image_Upscaling_IDELO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ISR
# Out:
# ...
#      |████████████████████████████████| 86.3 MB 67 kB/s
# ...
#      |████████████████████████████████| 3.8 MB 31.5 MB/s
# ...
#      |████████████████████████████████| 449 kB 54.2 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.7 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=98900564d49739336c638c9236c2d0a49979a4945d62a5a5fa69adc9c0f75b5c
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
# ...

# %%
pip install 'h5py<3.0.0'
# Out:
# ...
#      |████████████████████████████████| 2.9 MB 4.3 MB/s
# ...
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# ...

# %%
import os
from google.colab import files
import shutil

upload_folder = 'upload'
result_folder = 'results'

if os.path.isdir(upload_folder):
    shutil.rmtree(upload_folder)
if os.path.isdir(result_folder):
    shutil.rmtree(result_folder)
os.mkdir(upload_folder)
os.mkdir(result_folder)

# upload images
uploaded = files.upload()
for filename in uploaded.keys():
  dst_path = os.path.join(upload_folder, filename)
  print(f'move {filename} to {dst_path}')
  shutil.move(filename, dst_path)
# Out:
#      <input type="file" id="files-9a11351d-8858-49ff-a146-b6716499d3d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a11351d-8858-49ff-a146-b6716499d3d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 0a6d6e646541030505530c1d190b0c1f350f0c000d5d10170518120a5749524551104114024e454504136d09444a19084b455341450a5d53537266754815564a425e5c1763455f4315505e14584644420f5106464b145f125b40140900426d5d597320697b4c0e4e103b0b160872667412de759bf4c5.jpg to 0a6d6e646541030505530c1d190b0c1f350f0c000d5d10170518120a5749524551104114024e454504136d09444a19084b455341450a5d53537266754815564a425e5c1763455f4315505e14584644420f5106464b145f125b40140900426d5d597320697b4c0e4e103b0b160872667412de759bf4c5.jpg
# ...

# %%
import numpy as np
from PIL import Image

img = Image.open('/content/upload/0b6c64657255101c4910161401061b39090e1653444a41594441560d5248135240550d5041430c484a315e5b5e185c4546504312595f05004766756c04541c445006176759444044514b0d5517400a43065c1051585c16551b435c5543620a5015206973280d4f19083a01171f66756d5ed974f2f8e2.jpg')
img

# %%
# Uncomment if using local repo
# import sys
# sys.path.append('..')
from ISR.models import RDN, RRDN

#model = RDN(weights='noise-cancel')
#model_GAN = RRDN(weights='gans')
model_PSNR_small = RDN(weights='psnr-small')
#model_PSNR = RDN(weights='psnr-large')

# %%
#kk = img.resize(size=(1920, 1080), resample=Image.BICUBIC)

# %%
#GAN_Image = model_GAN.predict(np.array(img))
PSNR_Small_Image = model_PSNR_small.predict(np.array(img))
#PSNR_Image = model_PSNR.predict(np.array(img))

# %%
#Image_GAN = Image.fromarray(GAN_Image)
Image_PSNR_Small = Image.fromarray(PSNR_Small_Image)
#Image_PSNR = Image.fromarray(PSNR_Small_Image)

# %%
print(f"Actual Image Size: {img.size}")
#print(f"Scaled GAN Image Size: {Image_GAN.size}")
print(f"Scaled PSNR_Small Image Size: {Image_PSNR_Small.size}")
#print(f"Scaled PSNR Image Size: {Image_PSNR.size}")
# Out:
# Actual Image Size: (983, 552)
# Scaled PSNR_Small Image Size: (1966, 1104)

# %%
#GAN = Image_GAN.resize(size=(1920, 1080), resample=Image.LANCZOS)
PSNR_Small = Image_PSNR_Small.resize(size=(1920, 1080), resample=Image.LANCZOS)
#PSNR = Image_PSNR.resize(size=(1920, 1080), resample=Image.LANCZOS)

# %%
print(f"Actual Image Size: {img.size}")
#print(f"Scaled GAN Image Size: {GAN.size}")
print(f"Scaled PSNR_Small Image Size: {PSNR_Small.size}")
#print(f"Scaled PSNR Image Size: {PSNR.size}")
# Out:
# Actual Image Size: (983, 552)
# Scaled PSNR_Small Image Size: (1920, 1080)

# %%
PSNR_Small
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F19B3518F50>
